# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("sales.csv")
df["price"]=pd.to_numeric(df["price"],errors="coerce")
df["quantity"]=pd.to_numeric(df["quantity"],errors="coerce")
df=df.dropna(subset=["price","quantity"])
df["amount"]=df["price"]*df["quantity"]
df
# Out:
#          product      category    price  quantity     amount
# 1         Bottle   Accessories    150.0       2.0      300.0
# 3         Marker    Stationery     30.0       4.0      120.0
# 4         Laptop   Electronics  85000.0      12.0  1020000.0
# 5     Smartphone   Electronics  42000.0      25.0  1050000.0
# 6   Office Chair     Furniture   9500.0      10.0    95000.0
# 7            Pen    Stationery     25.0     500.0    12500.0
# 8       Backpack          Bags   1800.0      40.0    72000.0
# 9     Headphones   Electronics   3200.0      30.0    96000.0
# 10     Desk Lamp   Electronics   1500.0      18.0    27000.0
# 11    Coffee Mug   Kitchenware    450.0      60.0    27000.0

# %%
df.head()
# Out:
#         product      category    price  quantity     amount
# 1        Bottle   Accessories    150.0       2.0      300.0
# 3        Marker    Stationery     30.0       4.0      120.0
# 4        Laptop   Electronics  85000.0      12.0  1020000.0
# 5    Smartphone   Electronics  42000.0      25.0  1050000.0
# 6  Office Chair     Furniture   9500.0      10.0    95000.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10 entries, 1 to 11
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   product   10 non-null     str
#  1   category  10 non-null     str
#  2   price     10 non-null     float64
#  3   quantity  10 non-null     float64
#  4   amount    10 non-null     float64
# dtypes: float64(3), str(2)
# memory usage: 480.0 bytes

# %%
df.describe()
# Out:
#               price    quantity        amount
# count     10.000000   10.000000  1.000000e+01
# mean   14365.500000   70.100000  2.399920e+05
# std    27951.407483  152.086562  4.205787e+05
# min       25.000000    2.000000  1.200000e+02
# 25%      225.000000   10.500000  1.612500e+04
# 50%     1650.000000   21.500000  4.950000e+04
# 75%     7925.000000   37.500000  9.575000e+04
# max    85000.000000  500.000000  1.050000e+06

# %%
df.isnull().sum()
# Out:
# product     0
# category    0
# price       0
# quantity    0
# amount      0
# dtype: int64

# %% [markdown]
# Distribution Analysis

# %%
plt.hist(df["price"],bins=20)
plt.title("Histogram for Price")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Relationship Analysis

# %%
plt.scatter(df["price"],df["quantity"])
plt.title("Scatter plot between Price and Quantity")
plt.xlabel("Price")
plt.ylabel("Quantity")
plt.xticks(range(0,100000,10000))
plt.yticks(range(0,500,50))
plt.show()

# %% [markdown]
# Outlier Detection

# %%
sns.boxplot(x=df["price"])
plt.title("Boxplot of price")
plt.show()

# %% [markdown]
# Category Analysis

# %%
sales_cat=df.groupby("category")["amount"].sum()
plt.bar(sales_cat.index,sales_cat.values)
plt.title("Sales per category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()
